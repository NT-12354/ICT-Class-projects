# %%
income = float(input("lease enter your income: "))

def low():
    print("0%")
def llow():
    print("15%")
def mlow():
    print("20%")
def hlow():
    print("25%")
def middle():
    print("30%")
def high():
    print("35%")

if income <= 2000:
    low()
elif income > 2001 and income <= 4000:
    llow()
elif income > 4001 and income <= 7000:
    mlow()
elif income > 7001 and income <= 10000:
    hlow()
elif income > 10001 and income <= 14000:
    middle()
elif income > 14000:
    high()
# Out:
# lease enter your income:  40000
# 35%
