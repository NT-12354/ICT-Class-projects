# %%
def unit_conversion():
    value = float(input("enter your temperature: "))
    unit = input("Please enter your unit(celsius or fahrenheit): ")
    if unit == "celsius":
        print((value * 9/5) + 32, "fahrenheit")
    elif unit == "fahrenheit":
        print((value - 32) * 5/9, "celsius")
    else:
        print("please enter a proper value")

unit_conversion()
# Out:
# enter your temperature:  194.7
# Please enter your unit(celsius or fahrenheit):  celsius
# please enter a proper value
