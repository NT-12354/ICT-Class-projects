# %%
age = int(input("Enter your age: "))

def classify_person(age):
    if age <= 10:
        print("You are too young")
    
    elif age <= 20:
        print("Young, dumb and broke, innit!")
    
    elif age <= 30:
        print("you gotta do your best to make money!")
    
    elif age <= 45:
        print("Maturity is growing heaviliy inside you")
    
    elif age <= 70:
        print("you have to die or something bruv")
    
    else:
        age < 115
        print("It's enough, go back to who made you")

classify_person(age)
# Out:
# Enter your age:  25
# you gotta do your best to make money!
